# %% [markdown]
# # Task 5
# A'zra Zulaikha Binti Zainol
# P137262

# %%
persons = {
    "person1" : {
        "first_name" : "Diana",
        "last_name" : "Abdul Kahar",
        "age" : 34,
        "hometown" : "Perak",
        "favourite_foods" : ["Sushi", "Mango sticky rice", "Tomyam"],
        "hobbies" : ["Reading books", "Watching movies", "Playing games"]
    },
    "person2" : {
        "first_name" : "Ruzana",
        "last_name" : "Kamsul",
        "age" : 24,
        "hometown" : "Kedah",
        "favourite_foods" : ["Sushi", "Pasta", "Macaron"],
        "hobbies" : ["Listen to music", "Painting", "Singing"]
    },
    "person3" : {
        "first_name" : "Michael",
        "last_name" : "Robin",
        "age" : 40,
        "hometown" : "California",
        "favourite_foods" : ["Sambal petai", "Korean fried chicken", "Roti tisu"],
        "hobbies" : ["Cycling", "Hiking", "Gardening"]
    },
    "person4" : {
        "first_name" : "Alan",
        "last_name" : "Jay",
        "age" : 27,
        "hometown" : "Sarawak",
        "favourite_foods" : ["Fruit salad", "Fried rice", "Beef stew"],
        "hobbies" : ["Picnic", "Journaling", "Taking pictures"]
    },
    "person5" : {
        "first_name" : "Stellar",
        "last_name" : "Evergreen",
        "age" : 22,
        "hometown" : "London",
        "favourite_foods" : ["Dumplings", "Instant noodles", "Spicy chicken"],
        "hobbies" : ["Playing badminton", "Writing", "Editing videos"]
    }   
}

# %%
for person, info in persons.items():
    print(f"\nInformation for {person}:")
    print(f"First Name: {info['first_name']}")
    print(f"Last Name: {info['last_name']}")
    print(f"Age: {info['age']}")
    print(f"Hometown: {info['hometown']}")
    
    print("\nFavourite Foods:")
    for food in info['favourite_foods']:
        print(f" - {food}")

    print("\nHobbies:")
    for hobby in info['hobbies']:
        print(f" - {hobby}")
# Out:
# Information for person1:
# First Name: Diana
# Last Name: Abdul Kahar
# Age: 34
# Hometown: Perak
#
# Favourite Foods:
#  - Sushi
#  - Mango sticky rice
#  - Tomyam
#
# Hobbies:
#  - Reading books
#  - Watching movies
#  - Playing games
#
# Information for person2:
# First Name: Ruzana
# Last Name: Kamsul
# Age: 24
# Hometown: Kedah
#
# Favourite Foods:
#  - Sushi
#  - Pasta
#  - Macaron
#
# Hobbies:
#  - Listen to music
#  - Painting
#  - Singing
#
# Information for person3:
# First Name: Michael
# Last Name: Robin
# Age: 40
# Hometown: California
#
# Favourite Foods:
#  - Sambal petai
#  - Korean fried chicken
#  - Roti tisu
#
# Hobbies:
#  - Cycling
#  - Hiking
#  - Gardening
#
# Information for person4:
# First Name: Alan
# Last Name: Jay
# Age: 27
# Hometown: Sarawak
#
# Favourite Foods:
#  - Fruit salad
#  - Fried rice
#  - Beef stew
#
# Hobbies:
#  - Picnic
#  - Journaling
#  - Taking pictures
#
# Information for person5:
# First Name: Stellar
# Last Name: Evergreen
# Age: 22
# ...
